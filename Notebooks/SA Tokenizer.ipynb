# %%
from tokenizers import ByteLevelBPETokenizer
from transformers import BertTokenizerFast
from pathlib import Path

# %%
path_tscpt = '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/'

# %%
paths = [str(x) for x in Path(path_tscpt).glob("**/*.txt")]

# %%
paths
# Out:
# ['/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200169348620200825_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200120093160210610_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100178121860210225_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100195082760200317_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001137036D0200720_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200133287620201003_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001504400C0200708_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200189949860200403_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100144876250210402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200111751140200129_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300102568530210824_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200139070240210115_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300134872750210507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200142752540210115_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300117227420191217_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200179366980200520_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100147148620201111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001687071A0200623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100179388020201117_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100172376830210105_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300152311960200416_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300193730850210517_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001128787A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001162473A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200132323420201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300192184120201102_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200163422320201008_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300154296840210324_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200118473870210303_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300181499930200729_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200119690830210808_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100105193560200302_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100188287840200813_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300127359530201214_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100172108480200502_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300173537220201029_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300113194450200217_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001225417A0200702_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100103483640200729_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001265092A0200615_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200112499540210111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100133545250210401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300136383740210201_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200140135550210420_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100134613720201109_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300189400860200421_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200176886960200401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100122392630200110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300138787030210322_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200124100740210113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300155955780200604_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300197321180200609_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100101876590200610_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200166004940210120_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200113478980200508_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200179705860200401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001145841A0200612_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100109542730201104_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100119859870200424_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100196122730210803_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100114948650210215_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300173735980200604_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200132805740210114_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100173058750210408_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100195598540200126_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300149764180200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300189092440210329_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300102987550210502_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100133759820201109_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001611353A0200622_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100100670290200610_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100192971180200505_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200193882480200522_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100166751360200311_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300176827380200605_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300155606530200726_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100177563750210408_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100154596460210222_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001497755A0200619_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100120114760200304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100147586860200308_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100194524060210605_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200117687780200509_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200157380340210118_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300160719630200903_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200183019640200211_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100183400440200813_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200168312440210120_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100134134360200306_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001544524C0200708_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300137758650210508_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100149690780200428_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001911866C0200715_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200141294340200203_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001717053A0200624_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300122536220191218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100164962530210104_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001183189A0200702_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200140591980210306_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300176841980200605_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300163758630200903_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200159953140200206_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100122561340200802_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200199928460210623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100147354160210220_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300179490740210208_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100170523750210407_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200163880580200518_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300179475480200605_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300150776650210511_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300177634820200102_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100172543380200502_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200196565130210822_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100179157240200812_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001620740C0200709_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300103490720201015_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200187589580200521_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100150848880200429_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300124211220191219_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001096793D0200718_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001113177A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001655941C0200710_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100102058730201221_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200122902840200817_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100125196640200803_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300101699230201210_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100179356450210409_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300125433780200529_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300125154950200219_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200139486760210615_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001045013A0200630_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300102443650210502_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300110666120191216_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200176906520191209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001322697A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300105377950200214_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100117839730200110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200126851440210113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200120659750210416_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200161257340210119_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001143885A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300173614840210208_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001845232C0200714_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200134669780200512_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300180460620200102_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300180349540210209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300136874180200601_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300183721660200420_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001659676A0191206_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300130120330210320_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300195236780200609_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200189892860200403_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200153190480200515_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100108033930200108_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200163337350210425_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300162614520191228_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100115870260200303_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100120886160200304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200146181080200514_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100159104860200310_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300190082650200228_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300104298920201015_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001373966A0200617_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200135810740200819_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100129713360200305_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200194236180200522_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200198815760200405_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001299342A0200705_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001323895A0200706_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200118548980200509_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300121748220191218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300100213180200523_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300161520640210205_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300172648140210207_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300168882260200419_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300179177430200907_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100199087660210301_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200179840240200210_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100187715720201118_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200111767340210111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300198289820200107_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001525587A0191203_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200191008560200403_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001847908A0200626_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200172431240200209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100198298460200317_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300105929650210503_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200191975640200213_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300130576020191220_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100121136040200915_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300163374860200417_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300189473920201031_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100132796750210401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001330574A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300134765520200722_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100103579430200107_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200166943830210310_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100189333660200316_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100131683530200113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001689418A0200623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100165248750210407_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001119354A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100150121040200116_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200130302420201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100161242850210406_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001155025A0200612_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300192557880200609_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300101577230210316_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001379145A0200617_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300128773650210506_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300156165030200902_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300122668920191218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200101763040200127_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300157834130200727_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200121199670210304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200109469860200319_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200153699850210422_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001531954A0191203_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200188085940200212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001316406A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300152419880200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001701834C0200711_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300153375020191226_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200162729740210119_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100147691680200428_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200182727030210819_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100137094230200114_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300151797750200224_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300183542150210515_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200133195560200324_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300176759130200728_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200112580950210415_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200199785480200523_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300156171320191226_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100199618420201120_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200163816020200824_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200141128760200326_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200139873350210420_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100108934930200108_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100122935230200111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200108081430210805_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001486647C0200707_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200116501430210807_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200156712340200206_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100144376320201110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100198942430210803_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300165103120191229_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200144435920201005_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300162234620191227_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200198112760200405_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200197043350210430_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200145777280210308_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300119321430201212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100117116330200110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300130957720191220_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200175554760200401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001287557A0200704_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300135537760200413_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100142874150210402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100187645960210604_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100148000140200806_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200194286140200213_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100197359460210606_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200121897240200130_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200180968360200401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100188946420201118_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300159340260200417_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300186221250200228_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200192269930200827_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001694422A0200623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200186106530210314_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100188615150210410_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300186904380200608_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300148021650210511_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200195548530210315_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100141945350210402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100116640930200110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100184159520201117_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300151479930200725_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300173203050200227_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100140781390210722_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300195909440210211_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001788940A0200625_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001135418A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300134412360200413_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100173717030210105_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100182548960200314_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200191777030210315_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300186123580200608_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001666762A0200623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001134583A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100144698150210402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100156146860210222_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001202229A0200613_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001217024A0200614_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100120094340200915_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300170718740210326_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100168800240200811_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200148217380200514_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300155574080200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200126209570210304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200150156380200515_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100146683020201111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200145735640200204_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001295073D0200722_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100130981240200804_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200184402260200402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200150344030210815_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100191317280190503_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300134565650210507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100117384330201223_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200187309960200402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300157224840210204_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100166729360200311_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200110117950210414_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100107312070200422_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100158768530210102_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100160396420201113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200132848820201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001634088A0191205_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200140491180210306_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300146290520191222_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001313739A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300113113350200217_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200105456150210414_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100167850560200311_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300145148450200223_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100105975060200302_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200119995920201001_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300141577930200723_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200145172180200514_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200187446840200212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001721366C0200712_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001324782A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200104206280200507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100100277240200729_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200107768520201121_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300151963360200416_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200116986180200509_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300105724730210317_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300146997530200724_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200121112030210809_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300102759450200214_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100188951640200124_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300161167640210325_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100111178460200303_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200159040540210119_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001213924A0200702_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200127000240210113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200131826520201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001250152A0200703_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300101571930201210_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200109227360210608_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300131636050210507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200134479440200819_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100158790720201113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100199873260210301_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300104748460200406_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300149558980200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300138798050200221_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300112606550210504_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300147320240210203_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300108530580200526_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300137435680200601_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300193908820201218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300124038430210319_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200146068650200820_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200181786760200402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001253016A0200703_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001153428D0200720_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100134137050210401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300188620160200421_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200148163160200326_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200109454460200319_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300154613720201026_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100120512450210330_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100124427930200111_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300189499030200909_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200162574840200207_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100199052260200317_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200185149130201207_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300154832680200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200112619020200930_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300148304720201023_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100129927140200804_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200190861880200521_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001144335D0200720_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100175099460200312_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300164173020201027_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300108322880200526_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100161264780200430_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100177013030210105_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300111144950210504_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001099324A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001342647A0200616_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300135643940210201_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100168791040200121_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100159108360200310_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300173797640210208_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300187425330200909_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200179299740200210_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100195200250210412_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200128349170210304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200114850730210806_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200123565260200322_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300115417260200408_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300107579020191214_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200176082320191209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200169385060200331_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001641933C0200710_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100109418340200730_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200177471420191209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100130135260200305_singlech.txt',
# ...
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100192297620201119_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100156614040200808_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300147316880200602_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200185006260200402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300150406130200724_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300116523550200218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200124706270210304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200187038340200212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100165896150210407_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300131794820191220_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300147046320191223_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100144134730200115_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300142733630200723_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100196681460200317_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100159293540200809_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300123568660200410_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200148826930201201_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300199133620200107_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200175485780200519_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200166883540210120_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200100656360200318_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100194811750210412_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200151288540210117_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200161373080200518_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200197629820191212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200116221260200320_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200118122670210303_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100100508060200301_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001593111A0191204_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100126874250210217_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001753196A0200624_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200137735960210614_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100120379160210522_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001840266A0200626_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100106833540200911_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200194063860200403_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300159166030200902_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200153752220201007_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300100570260200406_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200151350130210815_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300196183520200106_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300127325540210130_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001226013A0200614_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_3001293747D0200722_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300194680680200609_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100158908460210223_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001289529A0200704_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100199531620201120_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300165886520201027_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200177990080200519_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300162681920191228_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200193269480200522_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200150931840210117_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200133185820201003_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200156197580200516_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100161422640200810_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300132985950200220_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300110036320191216_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300124608350210506_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300177709280200605_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001716324C0200712_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300143433930200723_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100194000540200125_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100135341250210218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200109420670210302_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100145402950210402_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300152875380200603_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100121765860200304_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200156400120200821_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100124288650210217_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100130364860200305_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300144838580200602_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200121636940210112_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200104551180200507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100132832950210401_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100127003560200305_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001403616C0200707_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100102606590200610_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300119669050210505_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300133595050210507_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100181541220200924_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001252986A0200615_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100130592930200113_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300162671330200903_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300138561380200601_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300176328930200728_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001021931A0200629_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100158986340200809_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100142015340200805_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300100320820191212_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300141126640210202_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200125206620201001_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300122314250200219_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200130597420201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300107126550200215_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200178543240200210_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001846400A0200626_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100181988220201117_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300167002920191230_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001124260A0200612_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001703724A0191206_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001456205A0200618_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200172578330210817_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200166327740200207_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100136649260200306_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200177331580200519_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300144214340210202_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300193901420200106_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100186435050210410_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300157654960200416_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200127731220201002_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100118850630200110_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100198073840200815_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100129409530201107_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100141360680200427_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200106321240210109_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300105801580200526_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200155321740210118_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200112058680200508_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200173260340200209_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300122399720191218_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300167088730200904_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001101710A0200701_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300106383650210503_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100152382850210405_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300138564230201216_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300180637580200606_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001675794A0200623_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100156109530210101_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_100113928470200423_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300188106180200608_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300150758620191224_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_1001818516A0200625_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_2001812716C0200714_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300161234120191227_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_300199746250200301_singlech.txt',
#  '/Users/akshaykekuda/Desktop/CSR-SA/manual_score_transcriptions/single_ch/IRCall_200147047580210308_singlech.txt',
#  ...]

# %%
len(paths)
# Out:
# 14081

# %%
from tokenizers import BertWordPieceTokenizer
tokenizer = BertWordPieceTokenizer()
tokenizer.train(files=paths, vocab_size=52_000, min_frequency=2, special_tokens=[
    "[CLS]",
    "[PAD]",
    "[UNK]",
    "[MASK]",
    "[SEP]",
], show_progress=True)

# %%
tokenizer
# Out:
# Tokenizer(vocabulary_size=23063, model=BertWordPiece, unk_token=[UNK], sep_token=[SEP], cls_token=[CLS], pad_token=[PAD], mask_token=[MASK], clean_text=True, handle_chinese_chars=True, strip_accents=None, lowercase=True, wordpieces_prefix=##)

# %%
model_path = '../attention_model/sa_tokenizer/'
tokenizer.save_model(model_path)
# Out:
# ['../attention_model/sa_tokenizer/vocab.txt']

# %%
import os, json
with open(os.path.join(model_path, "config.json"), "w") as f:
  tokenizer_cfg = {
      "do_lower_case": True,
      "unk_token": "[UNK]",
      "sep_token": "[SEP]",
      "pad_token": "[PAD]",
      "cls_token": "[CLS]",
      "mask_token": "[MASK]",
      "model_max_length": 512,
      "max_len": 512,
  }
  json.dump(tokenizer_cfg, f)

# %%
tokenizer = BertTokenizerFast.from_pretrained(model_path, model_max_len=512, add_special_tokens=True)

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='../attention_model/sa_tokenizer/', vocab_size=23063, model_max_len=1000000000000000019884624838656, is_fast=True, padding_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
from transformers import DataCollatorForLanguageModeling

# %%
from torch.utils.data import Dataset, DataLoader, random_split

class MLMDataSet(Dataset):
    def __init__(self, paths, tokenizer):
        self.sentences = []
        for file in paths:
            with open(file, 'r') as f:
                sent = f.readlines()
                self.sentences.extend([line.strip('\n') for line in sent])
        self.tokenizer = tokenizer
    def __len__(self):
        return len(self.sentences)
    def __getitem__(self, idx):
        return self.tokenizer(self.sentences[idx])

# %%
mlm_ds = MLMDataSet(paths[:10], tokenizer)

# %%
train_size = int(0.8 * len(mlm_ds))
test_size = len(mlm_ds) - train_size
train_dataset, test_dataset = random_split(mlm_ds, [train_size, test_size])

# %%
collator = DataCollatorForLanguageModeling(tokenizer)
dataloader_transcripts_train = DataLoader(train_dataset, batch_size=4, shuffle=True,
                                                  collate_fn=collator.torch_call)
dataloader_transcripts_test = DataLoader(test_dataset, batch_size=4, shuffle=True,
                                                  collate_fn=collator.torch_call)

# %%
import torch.nn as nn
class MLMNetwork(nn.Module):
    def __init__(self, embedding_size, tokenizer, dropout_rate,num_heads):
        super(MLMNetwork, self).__init__()
        vocab_size = len(tokenizer)
        pad_idx = tokenizer.pad_token_id
        self.embedding = nn.Embedding(vocab_size, embedding_size, padding_idx = pad_idx)
        self.multihead_attn = nn.MultiheadAttention(embedding_size, dropout=dropout_rate, num_heads=num_heads, batch_first=True)
        self.fcn = nn.Linear(embedding_size, vocab_size)

    def forward(self, inputs):
        embed_output = self.embedding(inputs['input_ids'])
        padding_mask = inputs['attention_mask']==0
        query = key = value = embed_output
        attn_out, wt = self.multihead_attn(query, key, value, key_padding_mask=padding_mask)
        masked_indices = inputs['labels']!=-100
        
        masked_out = attn_out[masked_indices]
        out = self.fcn(masked_out)
        return out

# %%
import torch.optim as optim

model = MLMNetwork(128, tokenizer, 0.5, 2)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4)

# %%
len(dataloader_transcripts_train)
# Out:
# 119

# %%
len(dataloader_transcripts_test)
# Out:
# 119

# %%
from tqdm import tqdm
loss_arr = []
model.train()
for i in range(1):
    epoch_loss = 0
    for batch in tqdm(dataloader_transcripts_train):
        output = model(batch)
        labels = batch['labels'][batch['labels']!=-100]
        loss = criterion(output, labels)
        optimizer.zero_grad()
        epoch_loss += loss.detach().item()
        loss.backward()
        optimizer.step()
        loss_arr.append(loss.detach().item())
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|█████████████████████████████████████████| 119/119 [00:02<00:00, 40.04it/s]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(loss_arr)
plt.show()

# %%
ex = next(iter(dataloader_transcripts_test))

# %%
ex['labels']
# Out:
# tensor([[-100, -100, -100,  101, -100, -100,   22, -100, -100, -100, -100, -100,
#          -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
#          -100, -100, -100, -100],
#         [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
#          -100, -100,  456, -100, -100, -100, -100, -100, -100,  105, -100, -100,
#          -100, -100, -100, -100],
#         [-100, 1853,    7, -100, -100, -100, -100, -100, -100, -100, -100, -100,
#          -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
#          -100, -100, -100, -100],
#         [-100, -100,    5,  480,  101, 1042, -100, -100, -100, -100,  699, -100,
#          -100, -100, -100, -100, -100, -100, -100, -100,  786, -100, -100, -100,
#          -100, -100, -100, -100]])

# %%
[tokenizer.convert_ids_to_tokens(id) for id in ex['input_ids']]
# Out:
# [['[CLS]',
#   'what',
#   'is',
#   'it',
#   'i',
#   "'",
#   '[MASK]',
#   'sorry',
#   'oh',
#   'okay',
#   '.',
#   '[SEP]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]'],
#  ['[CLS]',
#   'today',
#   'is',
#   'the',
#   'second',
#   'so',
#   'your',
#   'payment',
#   'is',
#   'gonna',
#   'your',
#   'cancellation',
#   'dates',
#   'are',
#   '[MASK]',
#   'be',
#   'the',
#   'first',
#   'of',
#   'every',
#   'month',
#   '[MASK]',
#   'you',
#   'run',
#   'and',
#   'get',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MASK]',
#   '[MASK]',
#   '[SEP]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]'],
#  ['[CLS]',
#   'yeah',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'make',
#   'it',
#   'would',
#   'be',
#   '[MASK]',
#   'to',
#   'in',
#   'order',
#   'y',
#   "'",
#   'all',
#   'often',
#   'um',
#   'well',
#   '[MASK]',
#   '.',
#   '[SEP]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]',
#   '[PAD]']]

# %%
[id for id in ex['input_ids']]

# %%
ex['labels'][ex['labels']!=-100]
# Out:
# [tensor([[False, False, False,  True, False, False,  True, False, False, False,
#           False, False, False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False],
#          [False, False, False, False, False, False, False, False, False, False,
#           False, False, False, False,  True, False, False, False, False, False,
#           False,  True, False, False, False, False, False, False],
#          [False,  True,  True, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False, False, False,
#           False, False, False, False, False, False, False, False],
#          [False, False,  True,  True,  True,  True, False, False, False, False,
#            True, False, False, False, False, False, False, False, False, False,
#            True, False, False, False, False, False, False, False]])]

# %%
[tokenizer.convert_ids_to_tokens(id) for id in [ex['labels'][ex['labels']!=-100]]]
# Out:
# [['it',
#   'm',
#   'gonna',
#   'so',
#   'cat',
#   '.',
#   "'",
#   'cause',
#   'it',
#   'might',
#   'able',
#   'check']]

# %%
tokenizer.convert_ids_to_tokens(ex['labels'][ex['labels']!=-100])
# Out:
# ['it',
#  'm',
#  'gonna',
#  'so',
#  'cat',
#  '.',
#  "'",
#  'cause',
#  'it',
#  'might',
#  'able',
#  'check']

# %%
import torch
model.eval()
with torch.no_grad():
    for item in dataloader_transcripts_train:
        encoded_txt = item['input_ids']
        print("target", tokenizer.convert_ids_to_tokens(item['labels'][item['labels']!=-100]))
        pred = model(item)
        pred_ids = torch.argmax(pred, dim=-1)
        print("pred", tokenizer.convert_ids_to_tokens(pred_ids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vn/09p5ftzx1590mccq9qkrr0m00000gn/T/ipykernel_49920/2480484593.py in <module>
#       1 import torch
# ----> 2 model.eval()
#       3 with torch.no_grad():
#       4     for item in dataloader_transcripts_train:
#       5         encoded_txt = item['input_ids']
#
# NameError: name 'model' is not defined

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vn/09p5ftzx1590mccq9qkrr0m00000gn/T/ipykernel_49920/2355735933.py in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
pred_ids = torch.argmax(pred, dim=-1)
